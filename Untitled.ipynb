# %% [markdown]
# # Example usage of IDGDatasetBase
#
# IDGDatasetBase is DataLoader for image captioning.
#
# ## Parameters
#
# * dataset_path
#
#         Path to datast created by shells/pre_process.sh
#         dataset is saved to data/captions/converted/XXX/YYY.pkl as a default.
#
# * vocab_path
#
#         Path to vocabulary dictionary created by shells/pre_process.sh
#         vocalulary dictionary is save to data/vocab/XXX.pkl as a default.
#
# * img_root
#
#         Path to root directory that contains MSCOCO images.
#         This has to be specified when raw_caption is True.
#
# * img_feature_root
#
#         Path to root directory that contains image features.
#         This has to be specified when raw_caption is False.
#
# * raw_caption
#
#         when raw_caption is True, it returns list of tokenized captions.
#         if False, it returns numpy.nparray.
#
# * raw_img
#
#         When raw_img is True, it use raw images downloaded from MSCOCO dataset.
#         if False, it uses image features processed beforehand.
#         but this repository doesn't contain preprocessed image features.
#         So it can't be False.
#
# * img_mean
#
#         This parameter is used for preprocess images.
#         The default value is "imagenet", mean value of imagenet is substracted from each images.
#         if None, original RGB values are used.
#         You can specify mean values like (123.44, 355.22, 235.2)
#
# * img_size
#
#         Output size of image. Default size is (244, 244).
#         if image size is more/less than img_size, the image is automatically resized.
#
# * preload_features
#
#         When preload_features is True, all features preprocessed beforehand are preloaded onto RAM.
#         it consumes much RAM.
#         if dataset is MSCOCO train 2014 and each feature size is 2048, then it would takes about &GB.
#         But this parameter is also can't be used because This repository doesn't contain preprocessed
#         image features.
#         If you want to use preprocessed image features. you use ResNet or something to get them.

# %%
import chainer
from IDGDataset import IDGDatasetBase

# %%
# set paths
# if you use shells/pre_process_sh, dataset contains both image paths and captions, 
# and vocabulary dictionary is saved to designated directory like below.

dataset_path = "data/captions/converted/MSCOCO_captions/train2014.pkl"
vocab_path = "data/vocab/mscoco_train2014_vocab.pkl"
img_root = "data/images/original"
#img_feature_root = "data/images/ResNet50"

# %%
# set other configurations
# see help(IDGDatasetBase) for detail.
raw_caption = False
raw_img = True
img_mean = "imagenet"
img_size = (224,224)
preload_features = True

# %%
# load dataset using chainer.dataset.Mixin wrapper.
train_data = IDGDatasetBase(
                dataset_path,
                vocab_path,
                img_root=img_root,
                raw_caption=raw_caption,
                raw_img=raw_img,
                img_mean=img_mean,
                img_size=img_size,
                preload_features=preload_features
)

# %%
# preprocessed image and encoded caption can be loaded.
img, caption = train_data[1]
jjjjjjjjjkjjjjjjjjjjjjjjjk
print(img)
print(caption)
# Out:
# [[[ -85.255325    -81.398186    -73.19411    ...  -14.928864
#      -3.4185715    35.591484  ]
#   [ -82.90839     -93.30635     -76.30635    ...   -9.265175
#       7.305847     47.3059    ]
#   [ -83.29614     -70.13288     -89.00023    ...   -6.489624
#      -3.969635     -7.7549973 ]
#   ...
#   [ -89.29612     -89.04106     -92.7349     ...  146.63242
#     146.6528      145.20386   ]
#   [ -84.09198     -84.88788     -84.17357    ...  146.81613
#     145.63248     146.13248   ]
#   [ -89.22446     -77.29615     -88.765656   ...  148.16312
#     142.32632     142.47937   ]]
#
#  [[ -78.58512     -80.09532     -63.83002    ...  -30.493385
#     -19.513618     36.353554  ]
#   [ -83.33002     -83.360634    -79.08512    ...  -24.074593
#      -7.656563     46.28225   ]
#   [ -77.09532     -76.47288     -77.860634   ...  -11.809265
#     -15.411659    -13.941849  ]
#   ...
#   [-100.717766    -98.31984     -97.72798    ...   51.363853
#      48.75158      46.221     ]
#   [ -98.197395   -100.156525    -92.411606   ...   48.11904
#      45.792473     45.292473  ]
#   [ -80.3909      -76.564606    -82.60553    ...   46.465996
#      42.486305     41.567955  ]]
#
#  [[ -48.87388     -51.37388     -40.118767   ...   -1.5981369
#       3.5139465    74.45217   ]
#   [ -43.853462    -53.46572     -33.312645   ...   -0.26104736
#      15.1669235    81.70742   ]
#   [ -44.833054    -46.445297    -38.935097   ...   15.71862
#       4.2791214    -1.4655991 ]
#   ...
#   [ -79.455505    -80.618805    -85.27184    ...   33.605705
#      33.78936      27.605705  ]
#   [ -73.60858     -79.404465    -76.69018    ...   32.993553
#      28.891472     31.677177  ]
#   [ -58.934776    -55.179924    -63.588203   ...   32.564995
#      25.585304     28.809776  ]]]
# [   1    3  248  340   23    8    0 4069  164  285    2]

# %%
# index2token decode captions encoded.
# token2index encode tokenized captions.

img, caption = train_data[1]


dec_caption = train_data.index2token(caption)

print('decoded caption')
print(dec_caption)

re_encoded_caption = train_data.token2index(dec_caption)

print('encoded caption')
print(re_encoded_caption)
# Out:
# decoded caption
# ['<SOS>', 'a', 'long', 'restaurant', 'table', 'with', '<UNK>', 'rounded', 'back', 'chairs', '<EOS>']
# encoded caption
# [1, 3, 248, 340, 23, 8, 0, 4069, 164, 285, 2]

# %%
# You can get list of words by get_word_ids.
word_ids = train_data.get_word_ids

print(word_ids)
# Out:
# Counter({'irises': 8822, 'porcupine': 8821, 'dhl': 8820, 'fez': 8819, 'cutters': 8818, 'annual': 8817, 'wayland': 8816, 'pyramids': 8815, 'motorhome': 8814, 'dangled': 8813, 'philadelphia': 8812, 'exercises': 8811, 'cornfield': 8810, 'tinsel': 8809, 'crook': 8808, 'outcrop': 8807, 'kawasaki': 8806, 'flowerpot': 8805, 'indifferent': 8804, 'teresa': 8803, 'sprig': 8802, 'well-kept': 8801, 'peep': 8800, 'shadowed': 8799, 'windup': 8798, 'hurry': 8797, 'chocolate-covered': 8796, 'muzzled': 8795, 'rulers': 8794, 'cheerleader': 8793, 'headgear': 8792, 'boad': 8791, 'lieing': 8790, 'brakes': 8789, 'amusing': 8788, 'strategically': 8787, 'skyteam': 8786, 'disarray': 8785, 'puncher': 8784, 'coupons': 8783, 'cultural': 8782, 'dolphins': 8781, 'turbine': 8780, 'ottomans': 8779, 'mike': 8778, 'dangerously': 8777, 'canning': 8776, 'carpets': 8775, 'chiquita': 8774, 'minnesota': 8773, 'homey': 8772, 'simpsons': 8771, 'browning': 8770, 'constructing': 8769, 'heritage': 8768, 'condos': 8767, 'disposal': 8766, 'binders': 8765, 'torches': 8764, 'kneeled': 8763, 'smith': 8762, 'hurdles': 8761, 'battleship': 8760, 'pugs': 8759, 'tempting': 8758, 'duvet': 8757, 'hoody': 8756, 'pearl': 8755, 'comics': 8754, 'houseplant': 8753, 'spirit': 8752, 'sharpie': 8751, 'defense': 8750, 'expertly': 8749, 'roping': 8748, 'majestically': 8747, 'time-lapse': 8746, 'dented': 8745, 'flurry': 8744, 'chats': 8743, 'advertised': 8742, '>': 8741, 'muslim': 8740, 'pondering': 8739, 'problem': 8738, 'browses': 8737, 'sidecars': 8736, 'worshiping': 8735, 'continues': 8734, 'utilitarian': 8733, 'skim': 8732, 'bodyboard': 8731, 'reacting': 8730, 'tanning': 8729, 'layout': 8728, 'distinct': 8727, 'coffeemaker': 8726, 'adn': 8725, 'brochure': 8724, 'dark-colored': 8723, 'workings': 8722, 'octagonal': 8721, 'well-furnished': 8720, 'ruby': 8719, 'waterhole': 8718, 'parcel': 8717, 'watered': 8716, 'advancing': 8715, 'two-tiered': 8714, 'singer': 8713, 'screwed': 8712, 'nudging': 8711, 'manhattan': 8710, 'sas': 8709, 'hp': 8708, 'scanner': 8707, 'hortons': 8706, 'ballgame': 8705, 'christ': 8704, 'diorama': 8703, '00rd': 8702, 'homer': 8701, 'focuses': 8700, 'challenging': 8699, 'deformed': 8698, 'false': 8697, 'skate-park': 8696, 'counting': 8695, 'necked': 8694, 'indicated': 8693, 'oils': 8692, 'curiosity': 8691, 'coating': 8690, 'bubbling': 8689, 'partaking': 8688, 'cashews': 8687, 'skiiing': 8686, 'squad': 8685, 'idling': 8684, 'liquids': 8683, 'mini-fridge': 8682, 'cell-phone': 8681, 'set-up': 8680, 'ratchet': 8679, 'cheer': 8678, 'lampshade': 8677, 'sweatpants': 8676, 'pagoda': 8675, 'lily': 8674, 'nigh': 8673, 'loved': 8672, 'vents': 8671, 'belonging': 8670, 'reef': 8669, 'fiddling': 8668, 'bratwurst': 8667, 'correct': 8666, 'sundae': 8665, 'snuggle': 8664, 'politicians': 8663, 'tarps': 8662, 'benz': 8661, 'scrolling': 8660, 'stevens': 8659, 'barnyard': 8658, 'waiters': 8657, 'faint': 8656, 'flotation': 8655, 'blues': 8654, 'singular': 8653, 'delicous': 8652, 'ballpark': 8651, 'barrow': 8650, 'obscures': 8649, 'rockefeller': 8648, 'hogs': 8647, 'rags': 8646, 'salesman': 8645, 'circuit': 8644, 'manipulating': 8643, 'trombone': 8642, 'llamas': 8641, 'weapon': 8640, 'marathon': 8639, 'pendant': 8638, 'artifacts': 8637, 'facet': 8636, 'paddleboarding': 8635, 'subs': 8634, 'sleds': 8633, 'biathlon': 8632, 'knows': 8631, 'muscle': 8630, 'schoolbus': 8629, 'poked': 8628, 'troop': 8627, 'statement': 8626, 'outlets': 8625, 'rabbits': 8624, 'pinking': 8623, 'plugging': 8622, 'alien': 8621, 'somber': 8620, 'dandelions': 8619, 'stature': 8618, 'surveying': 8617, 'perked': 8616, 'bodyboarding': 8615, 'ability': 8614, 'dunk': 8613, 'tweezers': 8612, 'kickflip': 8611, 'creams': 8610, 'scrubs': 8609, 'overexposed': 8608, 'ladybug': 8607, 'intended': 8606, 'toronto': 8605, 'carring': 8604, 'tomatoe': 8603, 'conducting': 8602, 'collectible': 8601, 'plantain': 8600, 'fort': 8599, 'farther': 8598, 'belong': 8597, 'nibble': 8596, 'spouting': 8595, 'villa': 8594, 'modular': 8593, 'answering': 8 ...

# %%
# number of words
num_words = len(word_ids)

print('The number of words: %d' % num_words)
# Out:
# The number of words: 8823

# %%
# you can get <UNK> ratio by get_unk_rato
unk_ratio = train_data.get_unk_ratio

print('unk ratio: %.3f' %unk_ratio)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-4acf56982d40> in <module>()
#       1 # you can get <UNK> ratio by get_unk_rato
# ----> 2 unk_ratio = train_data.get_unk_ratio
#       3
#       4 print('unk ratio: %.3f' %unk_ratio)
#
# /media/matasuke/Ubuntu01/Projects/chainer-IDG-DataLoader/IDGDataset.py in get_unk_ratio(self)
#     292     def get_unk_ratio(self):
#     293         """get <UNK> ratio in self.captions"""
# --> 294         unk = sum((cap['caption'] == self.word_ids['<UNK>']).sum() for cap in self.captions)
#     295         words = sum(len(cap['caption']) for cap in self.captions)
#     296
#
# /media/matasuke/Ubuntu01/Projects/chainer-IDG-DataLoader/IDGDataset.py in <genexpr>(.0)
#     292     def get_unk_ratio(self):
#     293         """get <UNK> ratio in self.captions"""
# --> 294         unk = sum((cap['caption'] == self.word_ids['<UNK>']).sum() for cap in self.captions)
#     295         words = sum(len(cap['caption']) for cap in self.captions)
#     296
#
# AttributeError: 'bool' object has no attribute 'sum'

# %%
# you just need to send train_data to chainer.iterators.SerialIterators()
batchsize = 128
train_iter = chainer.iterators.SerialIterator(train_data, batchsize)
